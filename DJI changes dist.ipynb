# %%
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set(rc={'figure.figsize':(20, 10)})

# %%
data = yf.download(
        tickers = "^DJI",
        period = "max",
        interval = "1d",
    )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data['Open'].plot(title = 'DJI');

# %%
data['pct_change'] = data['Open'].pct_change()

# %%
mu = data['pct_change'].mean()
std = data['pct_change'].std()
print('mean: {:06f}'.format(mu))
print('std:  {:06f}'.format(std))
# Out:
# mean: 0.000381
# std:  0.010679

# %%
plt.hist(data['pct_change'], bins=200, density=True)
  
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 200)
p = norm.pdf(x, mu, std)
  
plt.plot(x, p, 'k:', linewidth=2)
title = "Dow Jones Index Changes Ontop of Normal Distribution".format(mu, std)
plt.title(title)
  
plt.xlim([-0.05, 0.05])
    
plt.show()

# %%
plt.hist(data['pct_change'], bins=100)

title = "Large Downward Swings".format(mu, std)
plt.title(title)
  
plt.xlim([xmin, -0.03])
plt.ylim([0, 18])
    
plt.show()

# %%
plt.hist(data['pct_change'], bins=100)

title = "Large Upward Swings".format(mu, std)
plt.title(title)
  
plt.xlim([0.03, xmax])
plt.ylim([0, 18])
    
plt.show()
